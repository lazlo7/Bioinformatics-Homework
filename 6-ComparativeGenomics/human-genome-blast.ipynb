# %%
import requests
import xml.etree.ElementTree as ET
import random

# %%
# Минимум и максимум длины каждой случайной последовательности.
sequence_min_length = 300
sequence_max_length = 1000
# Отсюда будем брать последовательности.
genome_url_format = "https://genome.ucsc.edu/cgi-bin/das/hg38/dna?segment=chr{chromosome}:{begin},{end}"

# %%
# Длины хромосом.
chromosome_lengths = {"1": 248956422,
                      "2": 242193529,
                      "3": 198295559,
                      "4": 190214555,
                      "5": 181538259,
                      "6": 170805979,
                      "7": 159345973,
                      "8": 145138636,
                      "9": 138394717,
                      "10": 133797422,
                      "11": 135086622,
                      "12": 133275309,
                      "13": 114364328,
                      "14": 107043718,
                      "15": 101991189,
                      "16": 90338345,
                      "17": 83257441,
                      "18": 80373285,
                      "19": 58617616,
                      "20": 64444167,
                      "21": 46709983,
                      "22": 50818468,
                      "X": 156040895,
                      "Y": 57227415}

# %%
# Получает случайный регион в геноме.
def get_random_genome_region():
    chromosome = random.choice(list(chromosome_lengths.keys()))
    sequence_length = random.randint(sequence_min_length, sequence_max_length)
    begin = random.randint(1, chromosome_lengths[chromosome] - sequence_length)
    end = begin + sequence_length

    return chromosome, begin, end

# %%
# Получает последовательность из генома.
def get_genome_sequence(chromosome: str, begin: int, end: int) -> str:    
    url = genome_url_format.format(chromosome=chromosome, begin=begin, end=end)
    r = requests.get(url)
    if r.status_code != 200:
        assert False, "Failed to open genome url"

    xml_root = ET.fromstring(r.text)
    sequence = xml_root[0][0]
    
    return sequence.text

# %%
sequence_header_format = ">chr={chromosome}|begin={begin}|end={end} "

# %%
def main(output_file):
    with open(output_file, "w") as f:
        for i in range(100):
            print(f"Getting sequence {i + 1}...")
            
            while True:
                chromosome, begin, end = get_random_genome_region()
                print(chromosome, begin, end)
                sequence = get_genome_sequence(chromosome, begin, end).upper()

                # Проверяем, чтобы было только A/T/G/C.
                restart = False
                for ch in sequence:
                    if ch not in "ATGC\n":
                        restart = True
                        break
                if restart:
                    continue                

                break
            
            f.writelines([sequence_header_format.format(chromosome=chromosome, begin=begin, end=end),
                          sequence])

# %%
main("./files/human-genome-blast-output.fasta")
# Out:
# Getting sequence 1...
# 3 162392568 162393050
# Getting sequence 2...
# 1 164222808 164223163
# Getting sequence 3...
# 2 169108457 169109258
# Getting sequence 4...
# 8 15505082 15505606
# Getting sequence 5...
# 5 55682123 55683043
# Getting sequence 6...
# 19 52361892 52362351
# Getting sequence 7...
# 15 93753250 93754241
# Getting sequence 8...
# 21 24681316 24681665
# Getting sequence 9...
# 7 128249309 128249654
# Getting sequence 10...
# 2 134079339 134080222
# Getting sequence 11...
# 22 3015213 3015794
# 7 139258118 139259007
# Getting sequence 12...
# 20 55488124 55488960
# Getting sequence 13...
# 12 107140945 107141274
# Getting sequence 14...
# 11 57556181 57557064
# Getting sequence 15...
# 10 103493610 103494557
# Getting sequence 16...
# 14 75980707 75981273
# Getting sequence 17...
# 15 67058012 67058582
# Getting sequence 18...
# 12 53857050 53857900
# Getting sequence 19...
# Y 23098063 23098647
# Getting sequence 20...
# 13 50929594 50930001
# Getting sequence 21...
# 16 56666769 56667664
# Getting sequence 22...
# 14 85325376 85325692
# Getting sequence 23...
# 20 15292159 15293032
# Getting sequence 24...
# 19 12941848 12942164
# Getting sequence 25...
# 1 197297032 197297873
# Getting sequence 26...
# 2 185948149 185949084
# Getting sequence 27...
# 8 92600336 92601163
# Getting sequence 28...
# 11 46444492 46445070
# Getting sequence 29...
# 10 67075012 67075592
# Getting sequence 30...
# Y 42387459 42388281
# 4 155345286 155345586
# Getting sequence 31...
# 2 176967149 176967804
# Getting sequence 32...
# X 88491820 88492812
# Getting sequence 33...
# Y 3046954 3047876
# Getting sequence 34...
# 17 67967627 67968044
# Getting sequence 35...
# 16 52274360 52275270
# Getting sequence 36...
# 21 16777052 16778018
# Getting sequence 37...
# 9 58115792 58116098
# 11 110134421 110135153
# Getting sequence 38...
# 17 68553205 68553970
# Getting sequence 39...
# 18 18592786 18593513
# Getting sequence 40...
# 11 57894131 57894500
# Getting sequence 41...
# 11 110197752 110198233
# Getting sequence 42...
# 12 48340356 48340881
# Getting sequence 43...
# 20 4284867 4285806
# Getting sequence 44...
# 21 21570241 21570680
# Getting sequence 45...
# 14 62427228 62427825
# Getting sequence 46...
# 7 158320387 158320752
# Getting sequence 47...
# 1 92830769 92831574
# Getting sequence 48...
# 17 38051023 38051479
# Getting sequence 49...
# 15 91126716 91127090
# Getting sequence 50...
# 13 8881822 8882388
# 15 53153327 53154146
# Getting sequence 51...
# 12 30470740 30471326
# Getting sequence 52...
# 13 25323714 25324688
# Getting sequence 53...
# 20 48950196 48951081
# Getting sequence 54...
# 3 110501512 110502091
# Getting sequence 55...
# 1 98832656 98833435
# Getting sequence 56...
# 4 106751559 106752314
# Getting sequence 57...
# 6 143874691 143875218
# Getting sequence 58...
# Y 12824237 12824538
# Getting sequence 59...
# 11 56296278 56297198
# Getting sequence 60...
# 3 144396804 144397134
# Getting sequence 61...
# 13 15591771 15592103
# 13 70397678 70398587
# Getting sequence 62...
# 18 47676699 47677307
# Getting sequence 63...
# 2 212141992 212142853
# Getting sequence 64...
# 10 85670539 85671479
# Getting sequence 65...
# 5 152520227 152520614
# Getting sequence 66...
# Y 10885690 10886470
# Getting sequence 67...
# 21 22937820 22938521
# Getting sequence 68...
# 12 120856891 120857383
# Getting sequence 69...
# 20 20470457 20470946
# Getting sequence 70...
# 11 64876143 64877138
# Getting sequence 71...
# 22 26205602 26206180
# Getting sequence 72...
# 10 63765571 63766016
# Getting sequence 73...
# 8 63814815 63815776
# Getting sequence 74...
# 16 48330249 48330950
# Getting sequence 75...
# 12 120750577 120751415
# Getting sequence 76...
# 5 75612241 75612990
# Getting sequence 77...
# 10 56813612 56814440
# Getting sequence 78...
# 7 74919088 74919967
# Getting sequence 79...
# 4 126348290 126349261
# Getting sequence 80...
# 20 5450856 5451637
# Getting sequence 81...
# 14 39305887 39306713
# Getting sequence 82...
# 13 32758490 32759468
# Getting sequence 83...
# X 74118542 74119507
# Getting sequence 84...
# 13 31901914 31902780
# Getting sequence 85...
# X 64208656 64209220
# Getting sequence 86...
# 18 71263883 71264227
# Getting sequence 87...
# X 82048428 82049162
# Getting sequence 88...
# 5 169815678 169816228
# Getting sequence 89...
# Y 31917819 31918465
# 7 158475414 158476070
# Getting sequence 90...
# 22 44542812 44543680
# Getting sequence 91...
# 7 32469196 32469840
# Getting sequence 92...
# 9 90069404 90069827
# Getting sequence 93...
# 15 87587423 87588166
# Getting sequence 94...
# 13 45875224 45875934
# Getting sequence 95...
# 21 32824261 32824920
# Getting sequence 96...
# X 83867702 83868409
# Getting sequence 97...
# 16 2899171 2899782
# Getting sequence 98...
# 1 56072096 56072860
# Getting sequence 99...
# 3 124795556 124796373
# Getting sequence 100...
# 11 3368169 3368696
